# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading data set into environment

# %%
data=pd.read_csv('mushrooms.csv')
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
data.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
data.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [markdown]
# # Preprocessing

# %%
#Label encoding

# %%
from sklearn.preprocessing import LabelEncoder
lab_ec=LabelEncoder()
for i in data:
    data[i]=lab_ec.fit_transform(data[i])

# %%
data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
#splitting the data into features and target

# %%
x=data.drop(['class'],axis=1)
y=data['class']

# %%
#Min Max scaling

# %%
x.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      3.348104     1.827671     4.504677     0.415559     4.144756
# std       1.604329     1.229873     2.545821     0.492848     2.103729
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     3.000000     0.000000     2.000000
# 50%       3.000000     2.000000     4.000000     0.000000     5.000000
# 75%       5.000000     3.000000     8.000000     1.000000     5.000000
# max       5.000000     3.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      8124.000000   8124.000000  8124.000000  8124.000000  8124.000000
# mean          0.974151      0.161497     0.309207     4.810684     0.567208
# std           0.158695      0.368011     0.462195     3.540359     0.495493
# min           0.000000      0.000000     0.000000     0.000000     0.000000
# 25%           1.000000      0.000000     0.000000     2.000000     0.000000
# 50%           1.000000      0.000000     0.000000     5.000000     1.000000
# 75%           1.000000      0.000000     1.000000     7.000000     1.000000
# max           1.000000      1.000000     1.000000    11.000000     1.000000
#
#        ...  stalk-surface-below-ring  stalk-color-above-ring  \
# count  ...               8124.000000             8124.000000
# mean   ...                  1.603644                5.816347
# std    ...                  0.675974                1.901747
# min    ...                  0.000000                0.000000
# 25%    ...                  1.000000                6.000000
# 50%    ...                  2.000000                7.000000
# 75%    ...                  2.000000                7.000000
# max    ...                  3.000000                8.000000
#
#        stalk-color-below-ring  veil-type   veil-color  ring-number  \
# count             8124.000000     8124.0  8124.000000  8124.000000
# mean                 5.794682        0.0     1.965534     1.069424
# std                  1.907291        0.0     0.242669     0.271064
# min                  0.000000        0.0     0.000000     0.000000
# 25%                  6.000000        0.0     2.000000     1.000000
# 50%                  7.000000        0.0     2.000000     1.000000
# 75%                  7.000000        0.0     2.000000     1.000000
# max                  8.000000        0.0     3.000000     2.000000
#
#          ring-type  spore-print-color   population      habitat
# count  8124.000000        8124.000000  8124.000000  8124.000000
# mean      2.291974           3.596750     3.644018     1.508616
# std       1.801672           2.382663     1.252082     1.719975
# min       0.000000           0.000000     0.000000     0.000000
# 25%       0.000000           2.000000     3.000000     0.000000
# 50%       2.000000           3.000000     4.000000     1.000000
# 75%       4.000000           7.000000     4.000000     2.000000
# max       4.000000           8.000000     5.000000     6.000000
#
# [8 rows x 22 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler(feature_range=(0,1))
x=scale.fit_transform(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#                 0            1            2            3            4   \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.669621     0.609224     0.500520     0.415559     0.518095
# std       0.320866     0.409958     0.282869     0.492848     0.262966
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.400000     0.000000     0.333333     0.000000     0.250000
# 50%       0.600000     0.666667     0.444444     0.000000     0.625000
# 75%       1.000000     1.000000     0.888889     1.000000     0.625000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8            9   ...  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000  ...
# mean      0.974151     0.161497     0.309207     0.437335     0.567208  ...
# std       0.158695     0.368011     0.462195     0.321851     0.495493  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       1.000000     0.000000     0.000000     0.181818     0.000000  ...
# 50%       1.000000     0.000000     0.000000     0.454545     1.000000  ...
# 75%       1.000000     0.000000     1.000000     0.636364     1.000000  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#                 12           13           14      15           16  \
# count  8124.000000  8124.000000  8124.000000  8124.0  8124.000000
# mean      0.534548     0.727043     0.724335     0.0     0.655178
# std       0.225325     0.237718     0.238411     0.0     0.080890
# min       0.000000     0.000000     0.000000     0.0     0.000000
# 25%       0.333333     0.750000     0.750000     0.0     0.666667
# 50%       0.666667     0.875000     0.875000     0.0     0.666667
# 75%       0.666667     0.875000     0.875000     0.0     0.666667
# max       1.000000     1.000000     1.000000     0.0     1.000000
#
#                 17           18           19           20           21
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.534712     0.572994     0.449594     0.728804     0.251436
# std       0.135532     0.450418     0.297833     0.250416     0.286663
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.500000     0.000000     0.250000     0.600000     0.000000
# 50%       0.500000     0.500000     0.375000     0.800000     0.166667
# 75%       0.500000     1.000000     0.875000     0.800000     0.333333
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 22 columns]

# %%
#Training the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %% [markdown]
# # Model

# %% [markdown]
# >Naive-Bayes classifier Models

# %%
#gaussian naive-bayes classifier

# %%
from sklearn.naive_bayes import GaussianNB
g_model=GaussianNB()
g_model.fit(x_train,y_train)
y_pred=g_model.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
print('Accuracy score is:',accuracy_score(y_pred,y_test))
print('confusion matrix:',confusion_matrix(y_pred,y_test))
# Out:
# Accuracy score is: 0.9218461538461539
# confusion matrix: [[771  55]
#  [ 72 727]]

# %%
#Bernoulli naive-bayes classifier

# %%
from sklearn.naive_bayes import BernoulliNB
B_model=BernoulliNB()
B_model.fit(x_train,y_train)
y_pred=B_model.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
print('Accuracy score is:',accuracy_score(y_pred,y_test))
print('confusion matrix:',confusion_matrix(y_pred,y_test))
# Out:
# Accuracy score is: 0.8418461538461538
# confusion matrix: [[797 211]
#  [ 46 571]]

# %%
#Multinomial naive-bayes classifier

# %%
from sklearn.naive_bayes import MultinomialNB
m_model=MultinomialNB()
m_model.fit(x_train,y_train)
y_pred=m_model.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
print('Accuracy score is:',accuracy_score(y_pred,y_test))
print('confusion matrix:',confusion_matrix(y_pred,y_test))
# Out:
# Accuracy score is: 0.8615384615384616
# confusion matrix: [[792 174]
#  [ 51 608]]

# %%
#complement naive-bayes classifier

# %%
from sklearn.naive_bayes import ComplementNB
c_model=ComplementNB()
c_model.fit(x_train,y_train)
y_pred=m_model.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
print('Accuracy score is:',accuracy_score(y_pred,y_test))
print('confusion matrix:',confusion_matrix(y_pred,y_test))
# Out:
# Accuracy score is: 0.8615384615384616
# confusion matrix: [[792 174]
#  [ 51 608]]

# %% [markdown]
# >other ML models

# %%
#Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
print('Accuracy score is:',accuracy_score(y_pred,y_test))
print('confusion matrix:',confusion_matrix(y_pred,y_test))
# Out:
# Accuracy score is: 1.0
# confusion matrix: [[843   0]
#  [  0 782]]

# %%
#Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
print('Accuracy score is:',accuracy_score(y_pred,y_test))
print('confusion matrix:',confusion_matrix(y_pred,y_test))
# Out:
# Accuracy score is: 1.0
# confusion matrix: [[843   0]
#  [  0 782]]

# %%
#support vector classifier

# %%
from sklearn.svm import SVC
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
print('Accuracy score is:',accuracy_score(y_pred,y_test))
print('confusion matrix:',confusion_matrix(y_pred,y_test))
# Out:
# Accuracy score is: 0.9483076923076923
# confusion matrix: [[802  43]
#  [ 41 739]]

# %%
#logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print('Accuracy score is:',accuracy_score(y_pred,y_test))
print('confusion matrix:',confusion_matrix(y_pred,y_test))
# Out:
# Accuracy score is: 0.9489230769230769
# confusion matrix: [[802  42]
#  [ 41 740]]

# %%
#KNN model

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values=[]
n_neighbors=np.arange(3,15)
for i in n_neighbors:
    knn_model=KNeighborsClassifier(n_neighbors=i,metric='minkowski')
    knn_model.fit(x_train,y_train)
    knn_model.predict(x_test)
    acc=accuracy_score(y_test,y_pred)
    acc_values.append(acc)

# %%
plt.plot(n_neighbors,acc_values,'o-')
plt.xlabel('No. of Neighbors')
plt.ylabel('accuracy score')
# Out:
# Text(0, 0.5, 'accuracy score')

# %%
#accuracy is same for any number of neighbors plotted..hence we take n_neighbors=8

# %%
knn_model=KNeighborsClassifier(n_neighbors=8,metric='minkowski')
knn_model.fit(x_train,y_train)
knn_model.predict(x_test)
print('Accuracy score is:',accuracy_score(y_pred,y_test))
print('confusion matrix:',confusion_matrix(y_pred,y_test))
# Out:
# Accuracy score is: 0.9489230769230769
# confusion matrix: [[802  42]
#  [ 41 740]]
