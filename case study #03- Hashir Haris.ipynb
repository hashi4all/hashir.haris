# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('add_sales_data_2018.csv')

# %%
data.head()
# Out:
#          Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0  2018-10-08              208.00              222.25              206.85
# 1  2018-10-05              217.00              218.60              205.90
# 2  2018-10-04              223.50              227.80              216.15
# 3  2018-10-03              230.00              237.50              225.75
# 4  2018-10-01              234.55              234.60              221.05
#
#    Add4(in Thousands)  Add5(in Thousands)  Profit(in Thousands)
# 0              216.00              215.15              4093.065
# 1              210.25              209.20              4042.448
# 2              217.25              218.20              4213.819
# 3              226.45              227.60              4391.665
# 4              230.30              230.90              4350.683

# %% [markdown]
# # 1). First of all, check whether there is any relationship between the amount  spent for advertising through five different companies and profit  generated.

# %%
#visualizing correlation matrix into a heat map

# %%
corrmatrix= data.corr()
plt.subplots(figsize=(20,15))
sns.heatmap(corrmatrix,annot=True,linewidth=0.8,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
#From the heat map, Profit has strong positive correlation value of 0.99, 1, 0.99, 0.99, 0.99 with Add1, Add2, Add3, Add4, Add5 respectively.

# %% [markdown]
# # 2) Build a regression model to predict the profit from the given data and  comment your findings on it.

# %%
data.columns
# Out:
# Index(['Date', 'Add1(in Thousands)', 'Add2(in Thousands)',
#        'Add3(in Thousands)', 'Add4(in Thousands)', 'Add5(in Thousands)',
#        'Profit(in Thousands)'],
#       dtype='object')

# %%
#Defining variable x and y

# %%
y=data['Profit(in Thousands)']
x=data.drop(['Profit(in Thousands)','Date'],axis=1)

# %%
x.shape
# Out:
# (205, 5)

# %%
#splitting the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
#Modeling

# %%
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)

# %%
#setting up prediction variable

# %%
predictions=model.predict(x_test)

# %%
print(y_test)
# Out:
# 15     4152.066
# 9      4446.441
# 100    5131.898
# 132    4907.560
# 68     5004.282
# 95     4623.793
# 159    5384.175
# 162    5328.025
# 147    5175.051
# 182    5956.323
# 191    5780.799
# 164    4997.719
# 65     5075.858
# 175    5784.540
# 73     4936.120
# 152    5065.652
# 18     4190.965
# 82     5034.726
# 86     5015.536
# 143    5134.657
# 60     5145.131
# 101    5421.940
# 98     4569.293
# 30     4598.292
# 25     4436.321
# 16     4175.677
# 168    5616.791
# 195    5667.250
# 97     4648.834
# 194    5717.838
# 67     5001.615
# 120    5182.368
# 154    5017.503
# 202    5545.013
# 79     5013.207
# 69     5030.451
# 145    5108.626
# 55     4760.877
# 45     4606.340
# 84     4925.861
# 146    5250.788
# 66     5038.222
# 111    5491.792
# 153    5019.997
# 96     4647.356
# 38     4486.380
# 24     4435.174
# 139    5300.437
# 112    5425.190
# 29     4482.183
# 19     4193.095
# 178    6062.457
# Name: Profit(in Thousands), dtype: float64

# %%
predictions
# Out:
# array([4152.066, 4446.441, 5131.898, 4907.56 , 5004.282, 4623.793,
#        5384.175, 5328.025, 5175.051, 5956.323, 5780.799, 4997.719,
#        5075.858, 5784.54 , 4936.12 , 5065.652, 4190.965, 5034.726,
#        5015.536, 5134.657, 5145.131, 5421.94 , 4569.293, 4598.292,
#        4436.321, 4175.677, 5616.791, 5667.25 , 4648.834, 5717.838,
#        5001.615, 5182.368, 5017.503, 5545.013, 5013.207, 5030.451,
#        5108.626, 4760.877, 4606.34 , 4925.861, 5250.788, 5038.222,
#        5491.792, 5019.997, 4647.356, 4486.38 , 4435.174, 5300.437,
#        5425.19 , 4482.183, 4193.095, 6062.457])

# %%
#calculating mean squared error

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,predictions))
# Out:
# MSE is: 4.1359030627651384e-25

# %%
#mean squared error i.e residual between predicted and mean value is very low so the model is very accurate.

# %% [markdown]
# # 3) Predict the profit generated by the company, if they wish to spend the following amount for advertisement. Add1(in Thousands): 290, Add2(in Thousands): 312, Add3(in Thousands): 309, Add4(in Thousands): 298, Add5(in Thousands): 320

# %%
#substituting above advertisement amount into variable 'ad_amount' and predicting profit with above Regression Model.

# %%
ad_amount=[[290,312,309,298,320]]
profit=model.predict(ad_amount)

# %%
print(profit)
# Out:
# [5820.06]

# %%
#Profit generated by company for above mentioned ad amount is: 582.06
